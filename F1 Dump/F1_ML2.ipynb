# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

import pandas as pd
import requests
import json

plt.style.use("seaborn")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/GibranHamrouniCases/GibranHamrouniCases.github.io/main/F1_Tyres_Red.csv')
df.head(49)
# Out:
#               Driver   1   2   3   4   5   6    7    8    9  ...   49   50  \
# 0       Nico Rosberg  SS  SS  SS  SS  SS  SS   SS   SS   SS  ...    S    S
# 1     Lewis Hamilton  SS  SS  SS  SS  SS  SS   SS   SS   SS  ...    S    S
# 2     Kimi Raikkonen  SS  SS  SS  SS  SS  SS   SS   SS   SS  ...    S    S
# 3   Sebastian Vettel   S   S   S   S   S   S    S    S    S  ...   SS   SS
# 4   Daniel Ricciardo  SS  SS  SS  SS  SS  SS    S    S    S  ...    S    S
# 5       Daniil Kvyat  SS  SS  SS  SS  SS   S    S    S    S  ...    S    S
# 6     Lewis Hamilton  US  US  US  US  US  US   US    S    S  ...    S    S
# 7       Nico Rosberg  US  US  US  US  US  US   US   US    S  ...    S    S
# 8   Sebastian Vettel  US  US  US  US  US  US   US   US    S  ...   SS   SS
# 9     Max Verstappen  SS  SS  SS  SS  SS  SS   SS   SS   SS  ...    S    S
# 10  Daniel Ricciardo  SS  SS  SS  SS  SS  SS   SS   SS   SS  ...    S    S
# ...

# %%
#we have missing values
df_1 = df.fillna("")
df_1
# Out:
#               Driver   1   2   3   4   5   6   7   8   9  ...  49  50  51  52  \
# 0       Nico Rosberg  SS  SS  SS  SS  SS  SS  SS  SS  SS  ...   S   S   S   S
# 1     Lewis Hamilton  SS  SS  SS  SS  SS  SS  SS  SS  SS  ...   S   S   S   S
# 2     Kimi Raikkonen  SS  SS  SS  SS  SS  SS  SS  SS  SS  ...   S   S   S   S
# 3   Sebastian Vettel   S   S   S   S   S   S   S   S   S  ...  SS  SS  SS  SS
# 4   Daniel Ricciardo  SS  SS  SS  SS  SS  SS   S   S   S  ...   S   S   S   S
# 5       Daniil Kvyat  SS  SS  SS  SS  SS   S   S   S   S  ...   S   S   S   S
# 6     Lewis Hamilton  US  US  US  US  US  US  US   S   S  ...   S   S   S   S
# 7       Nico Rosberg  US  US  US  US  US  US  US  US   S  ...   S   S   S   S
# 8   Sebastian Vettel  US  US  US  US  US  US  US  US   S  ...  SS  SS  SS  SS
# 9     Max Verstappen  SS  SS  SS  SS  SS  SS  SS  SS  SS  ...   S   S   S   S
# 10  Daniel Ricciardo  SS  SS  SS  SS  SS  SS  SS  SS  SS  ...   S   S   S   S
# ...
